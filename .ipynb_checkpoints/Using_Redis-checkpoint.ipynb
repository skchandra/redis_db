# %%
import redis
from imdb import IMDb

# %%
r = redis.StrictRedis(host='localhost', port=6379, db=0)
pipe = r.pipeline()

# %%
from imdbpie import Imdb
imdb1 = Imdb()
imdb1 = Imdb(anonymize=True) # to proxy requests

# Creating an instance with caching enabled
# Note that the cached responses expire every 2 hours or so.
# The API response itself dictates the expiry time)
imdb1 = Imdb(cache=True)

# %%
top250 = imdb1.top_250()
dict_top250 = {}
for i in range(len(top250)):
    dict_top250[((top250[i]['tconst'].encode('utf-8'))[2:len(top250[i]['tconst'].encode('utf-8'))])] = (top250[i]['title'].encode('utf-8'))

# %%
dict_top250
# Out:
# {'0012349': 'The Kid',
#  '0015864': 'The Gold Rush',
#  '0017136': 'Metropolis',
#  '0017925': 'The General',
#  '0018455': 'Sunrise',
#  '0021749': 'City Lights',
#  '0022100': 'M',
#  '0025316': 'It Happened One Night',
#  '0027977': 'Modern Times',
#  '0031381': 'Gone with the Wind',
#  '0031679': 'Mr. Smith Goes to Washington',
#  '0032138': 'The Wizard of Oz',
#  '0032551': 'The Grapes of Wrath',
#  '0032553': 'The Great Dictator',
#  '0032976': 'Rebecca',
#  '0033467': 'Citizen Kane',
#  '0033870': 'The Maltese Falcon',
#  '0034583': 'Casablanca',
#  '0036775': 'Double Indemnity',
#  '0036868': 'The Best Years of Our Lives',
#  '0038650': "It's a Wonderful Life",
#  '0038787': 'Notorious',
#  '0040522': 'Bicycle Thieves',
#  '0040897': 'The Treasure of the Sierra Madre',
#  '0041959': 'The Third Man',
#  '0042192': 'All About Eve',
#  '0042876': 'Rashomon',
#  '0043014': 'Sunset Blvd.',
#  '0044079': 'Strangers on a Train',
#  '0044706': 'High Noon',
#  '0044741': 'Ikiru',
#  '0045152': "Singin' in the Rain",
#  '0046250': 'Roman Holiday',
#  '0046268': 'The Wages of Fear',
#  '0046911': 'Diabolique',
#  '0046912': 'Dial M for Murder',
#  '0047296': 'On the Waterfront',
#  '0047396': 'Rear Window',
#  '0047478': 'Seven Samurai',
#  '0047528': 'La Strada',
#  '0048424': 'The Night of the Hunter',
#  '0049406': 'The Killing',
#  '0050083': '12 Angry Men',
#  '0050212': 'The Bridge on the River Kwai',
#  '0050613': 'Throne of Blood',
#  '0050825': 'Paths of Glory',
#  '0050976': 'The Seventh Seal',
#  '0050986': 'Wild Strawberries',
#  '0051201': 'Witness for the Prosecution',
#  '0052311': 'Touch of Evil',
#  '0052357': 'Vertigo',
#  '0052561': 'Anatomy of a Murder',
#  '0052618': 'Ben-Hur',
#  '0053125': 'North by Northwest',
#  '0053198': 'The 400 Blows',
#  '0053291': 'Some Like It Hot',
#  '0053604': 'The Apartment',
#  '0053779': 'La Dolce Vita',
#  '0054215': 'Psycho',
#  '0054997': 'The Hustler',
#  '0055031': 'Judgment at Nuremberg',
#  '0055630': 'Yojimbo',
#  '0056172': 'Lawrence of Arabia',
#  '0056592': 'To Kill a Mockingbird',
#  '0056687': 'What Ever Happened to Baby Jane?',
#  '0056801': '8\xc2\xbd',
#  '0057012': 'Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb',
#  '0057115': 'The Great Escape',
#  '0058461': 'A Fistful of Dollars',
#  '0058946': 'The Battle of Algiers',
#  '0059578': 'For a Few Dollars More',
#  '0060196': 'The Good, the Bad and the Ugly',
#  '0060827': 'Persona',
#  '0061184': "Who's Afraid of Virginia Woolf?",
#  '0061512': 'Cool Hand Luke',
#  '0061722': 'The Graduate',
#  '0062622': '2001: A Space Odyssey',
#  '0064115': 'Butch Cassidy and the Sundance Kid',
#  '0064116': 'Once Upon a Time in the West',
#  '0066921': 'A Clockwork Orange',
#  '0068646': 'The Godfather',
#  '0070511': 'Papillon',
#  '0070735': 'The Sting',
#  '0071315': 'Chinatown',
#  '0071562': 'The Godfather: Part II',
#  '0071853': 'Monty Python and the Holy Grail',
#  '0072684': 'Barry Lyndon',
#  '0072890': 'Dog Day Afternoon',
#  '0073195': 'Jaws',
#  '0073486': "One Flew Over the Cuckoo's Nest",
#  '0074958': 'Network',
#  '0075148': 'Rocky',
#  '0075314': 'Taxi Driver',
#  '0075686': 'Annie Hall',
#  '0076759': 'Star Wars',
#  '0077416': 'The Deer Hunter',
#  '0078748': 'Alien',
#  '0078788': 'Apocalypse Now',
#  '0079470': 'Life of Brian',
#  '0079944': 'Stalker',
#  '0080678': 'The Elephant Man',
#  '0080684': 'Star Wars: Episode V - The Empire Strikes Back',
#  '0081398': 'Raging Bull',
#  '0081505': 'The Shining',
#  '0082096': 'Das Boot',
#  '0082971': 'Raiders of the Lost Ark',
#  '0083658': 'Blade Runner',
#  '0083922': 'Fanny and Alexander',
#  '0083987': 'Gandhi',
#  '0084787': 'The Thing',
#  '0086190': 'Star Wars: Episode VI - Return of the Jedi',
#  '0086250': 'Scarface',
#  '0086879': 'Amadeus',
#  '0087544': 'Nausica\xc3\xa4 of the Valley of the Wind',
#  '0087843': 'Once Upon a Time in America',
#  '0088247': 'The Terminator',
#  '0088763': 'Back to the Future',
#  '0089881': 'Ran',
#  '0090605': 'Aliens',
#  '0091763': 'Platoon',
#  '0092005': 'Stand by Me',
#  '0092067': 'Castle in the Sky',
#  '0093058': 'Full Metal Jacket',
#  '0093779': 'The Princess Bride',
#  '0095016': 'Die Hard',
#  '0095327': 'Grave of the Fireflies',
#  '0095765': 'Cinema Paradiso',
#  '0096283': 'My Neighbor Totoro',
#  '0097576': 'Indiana Jones and the Last Crusade',
#  '0099685': 'Goodfellas',
#  '0101414': 'Beauty and the Beast',
#  '0102926': 'The Silence of the Lambs',
#  '0103064': 'Terminator 2: Judgment Day',
#  '0105236': 'Reservoir Dogs',
#  '0105695': 'Unforgiven',
#  '0107048': 'Groundhog Day',
#  '0107207': 'In the Name of the Father',
#  '0107290': 'Jurassic Park',
#  '0108052': "Schindler's List",
#  '0109830': 'Forrest Gump',
#  '0110357': 'The Lion King',
#  '0110413': 'L\xc3\xa9on: The Professional',
#  '0110912': 'Pulp Fiction',
#  '0111161': 'The Shawshank Redemption',
#  '0111495': 'Three Colors: Red',
#  '0112471': 'Before Sunrise',
#  '0112573': 'Braveheart',
#  '0112641': 'Casino',
#  '0113247': 'La Haine',
#  '0113277': 'Heat',
#  '0114369': 'Se7en',
#  '0114709': 'Toy Story',
#  '0114746': 'Twelve Monkeys',
#  '0114787': 'Underground',
#  '0114814': 'The Usual Suspects',
#  '0116282': 'Fargo',
#  '0117951': 'Trainspotting',
#  '0118694': 'In the Mood for Love',
#  '0118715': 'The Big Lebowski',
#  '0118799': 'Life Is Beautiful',
#  '0119217': 'Good Will Hunting',
#  '0119488': 'L.A. Confidential',
#  '0119698': 'Princess Mononoke',
#  '0120382': 'The Truman Show',
#  '0120586': 'American History X',
#  '0120689': 'The Green Mile',
#  '0120735': 'Lock, Stock and Two Smoking Barrels',
#  '0120737': 'The Lord of the Rings: The Fellowship of the Ring',
#  '0120815': 'Saving Private Ryan',
#  '0133093': 'The Matrix',
#  '0137523': 'Fight Club',
#  '0167260': 'The Lord of the Rings: The Return of the King',
#  '0167261': 'The Lord of the Rings: The Two Towers',
#  '0167404': 'The Sixth Sense',
#  '0169547': 'American Beauty',
#  '0172495': 'Gladiator',
#  '0180093': 'Requiem for a Dream',
#  '0198781': 'Monsters, Inc.',
#  '0208092': 'Snatch.',
#  '0209144': 'Memento',
#  '0211915': 'Am\xc3\xa9lie',
#  '0245429': 'Spirited Away',
#  '0245712': 'Amores Perros',
#  '0246578': 'Donnie Darko',
#  '0253474': 'The Pianist',
#  '0266543': 'Finding Nemo',
#  '0266697': 'Kill Bill: Vol. 1',
#  '0268978': 'A Beautiful Mind',
#  '0317248': 'City of God',
#  '0325980': 'Pirates of the Caribbean: The Curse of the Black Pearl',
#  '0338013': 'Eternal Sunshine of the Spotless Mind',
#  '0338564': 'Infernal Affairs',
#  '0347149': "Howl's Moving Castle",
#  '0353969': 'Memories of Murder',
#  '0361748': 'Inglourious Basterds',
#  '0363163': 'Downfall',
#  '0364569': 'Oldboy',
#  '0372784': 'Batman Begins',
#  '0374546': 'Spring, Summer, Fall, Winter... and Spring',
#  '0381681': 'Before Sunset',
#  '0395169': 'Hotel Rwanda',
#  '0401792': 'Sin City',
#  '0405094': 'The Lives of Others',
#  '0405159': 'Million Dollar Baby',
#  '0407887': 'The Departed',
#  '0434409': 'V for Vendetta',
#  '0435761': 'Toy Story 3',
#  '0440963': 'The Bourne Ultimatum',
#  '0457430': "Pan's Labyrinth",
#  '0468569': 'The Dark Knight',
#  '0469494': 'There Will Be Blood',
#  '0477348': 'No Country for Old Men',
#  '0482571': 'The Prestige',
#  '0758758': 'Into the Wild',
#  '0816692': 'Interstellar',
#  '0848228': 'The Avengers',
#  '0892769': 'How to Train Your Dragon',
#  '0910970': 'WALL\xc2\xb7E',
#  '0978762': 'Mary and Max',
#  '0993846': 'The Wolf of Wall Street',
#  '1028532': "Hachi: A Dog's Tale",
#  '1049413': 'Up',
#  '1130884': 'Shutter Island',
#  '1187043': '3 Idiots',
#  '1201607': 'Harry Potter and the Deathly Hallows: Part 2',
#  '1205489': 'Gran Torino',
#  '1220719': 'Ip Man',
#  '1255953': 'Incendies',
#  '1291584': 'Warrior',
#  '1305806': 'The Secret in Their Eyes',
#  '1345836': 'The Dark Knight Rises',
#  '1375666': 'Inception',
#  '1392190': 'Mad Max: Fury Road',
#  '1392214': 'Prisoners',
#  '1454029': 'The Help',
#  '1504320': "The King's Speech",
#  '1675434': 'The Intouchables',
#  '1832382': 'A Separation',
#  '1853728': 'Django Unchained',
#  '1979320': 'Rush',
#  '2015381': 'Guardians of the Galaxy',
#  '2024544': '12 Years a Slave',
#  '2084970': 'The Imitation Game',
#  '2096673': 'Inside Out',
#  '2106476': 'The Hunt',
#  '2267998': 'Gone Girl',
#  '2278388': 'The Grand Budapest Hotel',
#  '2582802': 'Whiplash',
#  '3011894': 'Wild Tales',
#  '3659388': 'The Martian'}

# %%
dict_top250.keys()
# Out:
# ['0482571',
#  '0057115',
#  '0083987',
#  '2084970',
#  '0071562',
#  '0045152',
#  '1049413',
#  '0078788',
#  '0038787',
#  '0073486',
#  '0112573',
#  '0338013',
#  '0119488',
#  '2015381',
#  '0211915',
#  '0434409',
#  '0338564',
#  '0052357',
#  '0032551',
#  '0167261',
#  '0167260',
#  '0113277',
#  '0042876',
#  '0041959',
#  '0034583',
#  '2582802',
#  '0266543',
#  '0080678',
#  '0050083',
#  '0440963',
#  '0070511',
#  '0048424',
#  '0052618',
#  '0075686',
#  '0114746',
#  '0068646',
#  '0103064',
#  '0093058',
#  '0038650',
#  '0107048',
#  '0022100',
#  '0053779',
#  '0050825',
#  '0044741',
#  '0051201',
#  '1979320',
#  '0325980',
#  '0468569',
#  '1255953',
#  '0111495',
#  '0435761',
#  '0105695',
#  '0056172',
#  '0209144',
#  '0086250',
#  '0110357',
#  '1291584',
#  '0052561',
#  '0087544',
#  '0112641',
#  '0046912',
#  '0046911',
#  '0120586',
#  '0093779',
#  '0015864',
#  '0119698',
#  '0095327',
#  '0372784',
#  '0120815',
#  '1504320',
#  '0060827',
#  '0477348',
#  '0031381',
#  '2024544',
#  '0087843',
#  '0082971',
#  '0066921',
#  '0046250',
#  '0054215',
#  '0101414',
#  '0469494',
#  '0057012',
#  '0072684',
#  '0353969',
#  '0118694',
#  '0017925',
#  '0049406',
#  '0072890',
#  '0116282',
#  '0043014',
#  '0268978',
#  '0083922',
#  '0363163',
#  '0405159',
#  '0266697',
#  '0120382',
#  '0114814',
#  '0084787',
#  '3659388',
#  '0036775',
#  '1832382',
#  '0172495',
#  '0047396',
#  '0055031',
#  '0102926',
#  '0109830',
#  '0033467',
#  '0046268',
#  '0364569',
#  '0081398',
#  '0086879',
#  '0050986',
#  '0050212',
#  '0119217',
#  '0062622',
#  '0040522',
#  '1130884',
#  '0113247',
#  '1375666',
#  '0137523',
#  '1853728',
#  '0092067',
#  '0053291',
#  '0025316',
#  '0079470',
#  '0054997',
#  '0050976',
#  '0407887',
#  '0070735',
#  '0080684',
#  '0107207',
#  '0032553',
#  '1675434',
#  '0056801',
#  '2278388',
#  '0078748',
#  '0208092',
#  '1187043',
#  '0056592',
#  '0097576',
#  '0457430',
#  '1392214',
#  '0047528',
#  '0245429',
#  '0061184',
#  '0077416',
#  '0033870',
#  '0027977',
#  '0095016',
#  '0110413',
#  '1345836',
#  '0118715',
#  '0095765',
#  '0076759',
#  '0044706',
#  '0246578',
#  '0061722',
#  '0816692',
#  '0081505',
#  '0056687',
#  '1305806',
#  '2106476',
#  '0044079',
#  '0245712',
#  '0114709',
#  '0036868',
#  '0090605',
#  '0083658',
#  '0105236',
#  '0107290',
#  '0110912',
#  '0047478',
#  '0978762',
#  '0064116',
#  '0064115',
#  '0052311',
#  '2267998',
#  '0405094',
#  '0317248',
#  '0040897',
#  '0050613',
#  '0099685',
#  '0086190',
#  '0910970',
#  '1028532',
#  '0848228',
#  '3011894',
#  '0133093',
#  '0347149',
#  '0071315',
#  '0058946',
#  '0091763',
#  '0042192',
#  '0381681',
#  '0092005',
#  '0012349',
#  '0053125',
#  '0055630',
#  '0112471',
#  '0167404',
#  '0074958',
#  '0053604',
#  '0073195',
#  '1205489',
#  '0047296',
#  '0253474',
#  '0758758',
#  '0018455',
#  '0120689',
#  '0993846',
#  '0169547',
#  '0118799',
#  '1201607',
#  '0032138',
#  '0401792',
#  '0361748',
#  '0059578',
#  '0075314',
#  '1220719',
#  '0071853',
#  '0114369',
#  '0088247',
#  '0021749',
#  '0031679',
#  '0079944',
#  '0032976',
#  '0082096',
#  '1454029',
#  '0089881',
#  '0114787',
#  '0198781',
#  '0060196',
#  '1392190',
#  '0117951',
#  '0120735',
#  '0395169',
#  '0120737',
#  '0096283',
#  '0053198',
#  '0017136',
#  '0892769',
#  '0108052',
#  '0180093',
#  '0061512',
#  '0111161',
#  '0374546',
#  '0075148',
#  '0058461',
#  '0088763',
#  '2096673']

# %%
# for movId, title in dict_top250.iteritems():
#     imdb2 = IMDb()
#     my = imdb2.get_movie(movId)
#     for castMember in my['cast'][0:10]:
#         full_person = imdb2.get_person(castMember.getID(), info=["filmography"])
#         pipe.execute()
#         try:
#             r[castMember['name'].encode('utf-8')]
#         except KeyError: 
#             try:
#                 pipe.set(castMember.getID(), (castMember['name'].encode('utf-8'), full_person["actress"]))
#             except:
#                 pipe.set(castMember.getID(), (castMember['name'].encode('utf-8'), full_person["actor"]))

cast_dict = {}

for movId, title in dict_top250.iteritems():
    cast_list = []
#     print movId
    imdb2 = IMDb()
    my = imdb2.get_movie(movId)
#     pipe.execute()
    for castMember in my['cast'][0:10]:
#         cast_dict[castMember['name'].encode('utf-8')] = castMember.getID();
            cast_list.append(castMember.getID());
#     print cast_list
#     pipe.set(movId, cast_list);        
    cast_dict[movId] = cast_list
print cast_dict
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-28-0371f1f43036> in <module>()
#      19 #     print movId
#      20     imdb2 = IMDb()
# ---> 21     my = imdb2.get_movie(movId)
#      22 #     pipe.execute()
#      23     for castMember in my['cast'][0:10]:
#
# /home/kiki/anaconda/lib/python2.7/site-packages/IMDbPY-5.0-py2.7-linux-x86_64.egg/imdb/__init__.pyc in get_movie(self, movieID, info, modFunct)
#     409         if modFunct is not None:
#     410             movie.set_mod_funct(modFunct)
# --> 411         self.update(movie, info)
#     412         return movie
#     413
#
# /home/kiki/anaconda/lib/python2.7/site-packages/IMDbPY-5.0-py2.7-linux-x86_64.egg/imdb/__init__.pyc in update(self, mop, info, override)
#     770                 method = lambda *x: {}
#     771             try:
# --> 772                 ret = method(mopID)
#     773             except Exception, e:
#     774                 self._imdb_logger.critical('caught an exception retrieving ' \
#
# /home/kiki/anaconda/lib/python2.7/site-packages/IMDbPY-5.0-py2.7-linux-x86_64.egg/imdb/parser/http/__init__.pyc in get_movie_main(self, movieID)
#     504
#     505     def get_movie_main(self, movieID):
# --> 506         cont = self._retrieve(self.urls['movie_main'] % movieID + 'combined')
#     507         return self.mProxy.movie_parser.parse(cont, mdparse=self._mdparse)
#     508
#
# /home/kiki/anaconda/lib/python2.7/site-packages/IMDbPY-5.0-py2.7-linux-x86_64.egg/imdb/parser/http/__init__.pyc in _retrieve(self, url, size, _noCookies)
#     451         self._http_logger.debug('fetching url %s (size: %d)', url, size)
#     452         try:
# --> 453             ret = self.urlOpener.retrieve_unicode(url, size=size)
#     454         finally:
#     455             if _noCookies and _cookies:
#
# /home/kiki/anaconda/lib/python2.7/site-packages/IMDbPY-5.0-py2.7-linux-x86_64.egg/imdb/parser/http/__init__.pyc in retrieve_unicode(self, url, size)
#     204             if PY_VERSION > (2, 3) and not IN_GAE:
#     205                 kwds['size'] = size
# --> 206             content = uopener.read(**kwds)
#     207             self._last_url = uopener.url
#     208             # Maybe the server is so nice to tell us the charset...
#
# /home/kiki/anaconda/lib/python2.7/socket.pyc in read(self, size)
#     353             while True:
#     354                 try:
# --> 355                     data = self._sock.recv(rbufsize)
#     356                 except error, e:
#     357                     if e.args[0] == EINTR:
#
# KeyboardInterrupt:

# %%
for key, value in cast_dict.iteritems():
    if len(value) != 10:
        print key, len(value)

# %%
def test(movies):
    """input: list of 250 movies
        output: hashtable"""
    act_assoc_map = {}
    for movie in movies:
        l_act = movies.get(movie)
        for act in l_act:
            for act_id in range(len(l_act)):
                if act not in act_assoc_map.keys():
                    if l_act[act_id] != act:
                        act_assoc_map[act] = [l_act[act_id]]
                else:
                    if l_act[act_id] != act:
                        act_assoc_map[act].append(l_act[act_id])
    for actor in act_assoc_map.keys():
        act_assoc_map[actor] = list(set(act_assoc_map[actor]))
    return act_assoc_map

hashtable = test(cast_dict)
#print hashtable
for key, value in hashtable.iteritems():
    print str(value)
    pipe.execute();
    for i in value:
        pipe.lpush(key, i)

# %%
len(hashtable.keys())

# %%
for key, value in hashtable.iteritems():
    print len(value)

# %%
# pipe.execute()
# print r.keys()[0]
# print r.get(r.keys()[0])

# %%
# len(r.keys())

# %%
full_person = imdb2.get_person('0815495')

# %%
full_person
